# %% [markdown]
# # Image classification from scratch
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/04/27<br>
# **Last modified:** 2020/04/28<br>
# **Description:** Training an image classifier from scratch on the Kaggle Cats vs Dogs dataset.

# %% [markdown]
# ## Introduction
#
# This example shows how to do image classification from scratch, starting from JPEG
# image files on disk, without leveraging pre-trained weights or a pre-made Keras
# Application model. We demonstrate the workflow on the Kaggle Cats vs Dogs binary
#  classification dataset.
#
# We use the `image_dataset_from_directory` utility to generate the datasets, and
# we use Keras image preprocessing layers for image standardization and data augmentation.

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
import os
#from tensorflow import keras
#from tensorflow.keras import layers
import keras
import numpy
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, Activation, SeparableConv2D, add, GlobalAveragePooling2D
from tensorflow.keras.layers.experimental import preprocessing

from keras.engine.base_layer import InputSpec
#import readline

# %%
os.chdir('/media/jacoblamkey/Storage/club and lax wheat')
cwd = os.getcwd()
print(cwd)


try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
    print("Running on TPU ", tpu.cluster_spec().as_dict()["worker"])
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except ValueError:
    print("Not connected to a TPU runtime. Using CPU/GPU strategy")
    strategy = tf.distribute.MirroredStrategy()
# Out:
# /media/jacoblamkey/Storage/club and lax wheat
# Not connected to a TPU runtime. Using CPU/GPU strategy
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [markdown]
# ## Load the data: the Cats vs Dogs dataset
#
# ### Raw data download
#
# First, let's download the 786M ZIP archive of the raw data:

# %%
#!curl -O https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip

# %%
#!unzip -q kagglecatsanddogs_3367a.zip
#!ls

# %% [markdown]
# Now we have a `PetImages` folder which contain two subfolders, `Cat` and `Dog`. Each
#  subfolder contains image files for each category.

# %%
#!ls PetImages

# %% [markdown]
# ### Filter out corrupted images
#
# When working with lots of real-world image data, corrupted images are a common
# occurence. Let's filter out badly-encoded images that do not feature the string "JFIF"
#  in their header.

# %%
#import os

#num_skipped = 0
#for folder_name in ("Cat", "Dog"):
#    folder_path = os.path.join("PetImages", folder_name)
#    for fname in os.listdir(folder_path):
#        fpath = os.path.join(folder_path, fname)
#        try:
#            fobj = open(fpath, "rb")
#            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
#        finally:
#            fobj.close()#
#        if not is_jfif:
#            num_skipped += 1
            # Delete corrupted image
#            os.remove(fpath)

#print("Deleted %d images" % num_skipped)

# %%
print (tf.__version__)
print (keras.__version__)
# Out:
# 2.3.1
# 2.4.3

# %% [markdown]
# ## Generate a `Dataset`

# %%
image_size = (256, 256)
batch_size = 100

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "data/test_v2",
    validation_split=0.2,
    subset="training",
    seed=5120,
    image_size=image_size,
    batch_size=batch_size
    #smart_resize=True,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "data/test_v2",
    validation_split=0.2,
    subset="validation",
    seed=5120,
    image_size=image_size,
    batch_size=batch_size
     #smart_resize=Tru
    
)

train_ds = train_ds.prefetch(buffer_size=8)
val_ds = val_ds.prefetch(buffer_size=8)
# Out:
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.

# %%
val_ds
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# ## Visualize the data
#
# Here are the first 9 images in the training dataset. As you can see, label 1 is "dog"
#  and label 0 is "cat".

# %%
import matplotlib.pyplot as plt

#plt.figure(figsize=(10, 10))
#for images, labels in train_ds.take(1):
#    for i in range(9):
#        ax = plt.subplot(3, 3, i + 1)
#        plt.imshow(images[i].numpy().astype("uint8"))
#        plt.title(int(labels[i]))
#        plt.axis("off")

# %% [markdown]
# ## Using image data augmentation
#
# When you don't have a large image dataset, it's a good practice to artificially
# introduce sample diversity by applying random yet realistic transformations to the
# training images, such as random horizontal flipping or small random rotations. This
# helps expose the model to different aspects of the training data while slowing down
#  overfitting.

# %%
#data_augmentation = keras.Sequential(
#    [
#        layers.experimental.preprocessing.RandomFlip("horizontal"),
#        layers.experimental.preprocessing.RandomRotation(0.1),
#    ]
#)

# %% [markdown]
# Let's visualize what the augmented samples look like, by applying `data_augmentation`
#  repeatedly to the first image in the dataset:

# %%
#plt.figure(figsize=(10, 10))
#for images, _ in train_ds.take(1):
#    for i in range(9):
#        augmented_images = data_augmentation(images)
#        ax = plt.subplot(3, 3, i + 1)
#        plt.imshow(augmented_images[0].numpy().astype("uint8"))
#        plt.axis("off")

# %% [markdown]
# ## Standardizing the data
#
# Our image are already in a standard size (180x180), as they are being yielded as
# contiguous `float32` batches by our dataset. However, their RGB channel values are in
#  the `[0, 255]` range. This is not ideal for a neural network;
# in general you should seek to make your input values small. Here, we will
# standardize values to be in the `[0, 1]` by using a `Rescaling` layer at the start of
#  our model.

# %% [markdown]
# ## Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so we can yield data from disk without
#  having I/O becoming blocking:

# %%
train_ds = train_ds.prefetch(buffer_size=8)
val_ds = val_ds.prefetch(buffer_size=8)

# %% [markdown]
# ## Build a model
#
# We'll build a small version of the Xception network. We haven't particularly tried to
# optimize the architecture; if you want to do a systematic search for the best model
#  configuration, consider using
# [Keras Tuner](https://github.com/keras-team/keras-tuner).
#
# Note that:
#
# - We start the model with the `data_augmentation` preprocessor, followed by a
#  `Rescaling` layer.
# - We include a `Dropout` layer before the final classification layer.

# %%
mobsIN = {'mobE0': tf.keras.applications.EfficientNetB0(include_top=False,  weights="imagenet"),
          'mobE1': tf.keras.applications.EfficientNetB1(include_top=False,  weights="imagenet"), 
          'mobE2':tf.keras.applications.EfficientNetB2(include_top=False,  weights="imagenet") ,
          'mobE3':tf.keras.applications.EfficientNetB3(include_top=False,  weights="imagenet") ,
          'mobE4':tf.keras.applications.EfficientNetB4(include_top=False,  weights="imagenet") ,
          'mobE5':tf.keras.applications.EfficientNetB5(include_top=False,  weights="imagenet") ,
          'mobE6':tf.keras.applications.EfficientNetB6(include_top=False,  weights="imagenet") ,
          'mobE7':tf.keras.applications.EfficientNetB7(include_top=False,  weights="imagenet") ,
          'mobV1':tf.keras.applications.MobileNet(include_top=False,  weights="imagenet"),
          'mobV2':tf.keras.applications.MobileNetV2(include_top=False,  weights="imagenet") ,
          'mobD1':tf.keras.applications.DenseNet121(include_top=False,  weights="imagenet"),
          'mobD2':tf.keras.applications.DenseNet169(include_top=False,  weights="imagenet"),
          'mobD3':tf.keras.applications.DenseNet201(include_top=False,  weights="imagenet")
}
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
mobs = 'mobE0'
mobs
# Out:
# 'mobE0'

# %%
def schedule(epoch):
    def lr(epoch, start_lr, rampup_epochs, exp_decay):
        if epoch < rampup_epochs:
            return start_lr
        else:
            return start_lr * tf.math.exp(-exp_decay * epoch)
    return lr(epoch, start_lr, rampup_epochs, exp_decay)


with strategy.scope():

    def unfreeze_model(model):
        # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
        for layer in model.layers[-20:]:
            if not isinstance(layer, BatchNormalization):
                model.trainable = True

        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
        model.compile(
            optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"]
        )
        return model

    def imagenetModel( mob): 

        mobm = mobsIN[mob]
        model = keras.Sequential()

        model.add(keras.Input(shape=(256, 256, 3)))


        model.add(mobm)
        # Freeze the pretrained weights
        model.trainable = False

        # Rebuild top
        model.add(GlobalAveragePooling2D())
        model.add(BatchNormalization())

        top_dropout_rate = 0.18
        model.add(Dense(240, activation="softmax", name="dense"))
        model.add(Dropout(top_dropout_rate, name="top_dropout"))
        model.add(Dense(1, activation="sigmoid", name="pred"))

        # Compile
        #model = tf.keras.Model(inputs, outputs, name="EfficientNet")
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
        model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"]
        )
        del(mobm, mob)
        return model

    def fmodelLoop(fepoch, epochs, model):    

        model.fit(train_ds, epochs=fepoch, validation_data=val_ds, callbacks=callbacksF,
                  #steps_per_epoch = 549//batch_size,
                  #validation_steps = 137//batch_size,
                  batch_size=256,
                  workers=19,
                  use_multiprocessing=True,
                  shuffle=True,
                 )
        #plot_hist(hist)

        unfreeze_model(model)

        model.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=callbacks,
          #steps_per_epoch = 549//batch_size,
          #validation_steps = 137//batch_size,
          batch_size=256,
          workers=19,
          use_multiprocessing=True,
          shuffle=True,

         )
        return model

# %%
seed = 1
seed = str(seed)
seed
# Out:
# '1'

# %%
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
image_size = (256, 256)
batch_size = 64
seed=5
for seed in numpy.arange(1,10,1):
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "data/test_v2",
        validation_split=0.2,
        subset="training",
        seed=seed,
        image_size=image_size,
        batch_size=batch_size
        #smart_resize=True,
    )
    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "data/test_v2",
        validation_split=0.2,
        subset="validation",
        seed=seed,
        image_size=image_size,
        batch_size=batch_size
         #smart_resize=Tru
    
    )

    train_ds = train_ds.prefetch(buffer_size=8)
    val_ds = val_ds.prefetch(buffer_size=8)

    seed = str(seed)

    for i, mob in enumerate(['mobE0'
                             
                             #, 'mobE1'
                         #,'mobE2','mobE3','mobE4','mobE5','mobE6','mobE7'
                        #,'mobV1','mobV2','mobD1','mobD2','mobD3'
                        ]):

        callbacks = [keras.callbacks.ModelCheckpoint(mob+"_"+seed+"_save_{epoch}_{val_accuracy:.2f}.h5",save_best_only=True),
            keras.callbacks.ReduceLROnPlateau(monitor='val_loss',mode="auto", factor=0.18, 
                                              patience=3, min_lr=0.001)#,min_delta = 0.001)#,
            #keras.callbacks.LearningRateScheduler(schedule)
            ]
    
        callbacksF = [#keras.callbacks.ModelCheckpoint(mob+"_save_{epoch}_{val_accuracy:.2f}.h5",save_best_only=True),
            keras.callbacks.ReduceLROnPlateau(monitor='val_loss',mode="auto", factor=0.18, 
                                              patience=3, min_lr=0.001)#,min_delta = 0.001)#,
            #keras.callbacks.LearningRateScheduler(schedule)
            ]
    
        #ile = open("/media/jacoblamkey/Storage/"+mob+"_history.txt", 'w')
        print(mob)
        model=imagenetModel(mob=mob)

        fmodelLoop(fepoch = 2, epochs=100, model=model)
    
        del(model)
        #modelLoop(epochs=2)
        #print(reportHistory)
# Out:
# Number of devices: 2
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.
# mobE0
# Epoch 1/2
# 9/9 [==============================] - 6s 637ms/step - loss: 0.6926 - accuracy: 0.5464 - val_loss: 0.6928 - val_accuracy: 0.5912
# Epoch 2/2
# 9/9 [==============================] - 5s 551ms/step - loss: 0.6924 - accuracy: 0.5829 - val_loss: 0.6928 - val_accuracy: 0.5839
# Epoch 1/100
# 2/9 [=====>........................] - ETA: 1s - loss: 0.6926 - accuracy: 0.5234WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1274s vs `on_train_batch_end` time: 0.3159s). Check your callbacks.
# 9/9 [==============================] - 9s 1s/step - loss: 0.6914 - accuracy: 0.5792 - val_loss: 0.6927 - val_accuracy: 0.6058
# Epoch 2/100
# 9/9 [==============================] - 8s 893ms/step - loss: 0.6842 - accuracy: 0.7887 - val_loss: 0.6926 - val_accuracy: 0.7299
# Epoch 3/100
# 9/9 [==============================] - 8s 887ms/step - loss: 0.6756 - accuracy: 0.8470 - val_loss: 0.6925 - val_accuracy: 0.5693
# Epoch 4/100
# 9/9 [==============================] - 8s 841ms/step - loss: 0.6685 - accuracy: 0.8798 - val_loss: 0.6926 - val_accuracy: 0.4599
# Epoch 5/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6597 - accuracy: 0.8707 - val_loss: 0.6924 - val_accuracy: 0.4526
# Epoch 6/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.6519 - accuracy: 0.8998 - val_loss: 0.6924 - val_accuracy: 0.4526
# Epoch 7/100
# 9/9 [==============================] - 8s 850ms/step - loss: 0.6434 - accuracy: 0.9144 - val_loss: 0.6928 - val_accuracy: 0.4161
# Epoch 8/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.6374 - accuracy: 0.9162 - val_loss: 0.6929 - val_accuracy: 0.4453
# Epoch 9/100
# 9/9 [==============================] - 8s 879ms/step - loss: 0.6339 - accuracy: 0.9290 - val_loss: 0.6931 - val_accuracy: 0.4380
# Epoch 10/100
# 9/9 [==============================] - 7s 812ms/step - loss: 0.6273 - accuracy: 0.9326 - val_loss: 0.6938 - val_accuracy: 0.4234
# Epoch 11/100
# 9/9 [==============================] - 8s 875ms/step - loss: 0.6265 - accuracy: 0.9344 - val_loss: 0.6934 - val_accuracy: 0.4526
# Epoch 12/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6247 - accuracy: 0.9326 - val_loss: 0.6929 - val_accuracy: 0.4453
# Epoch 13/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.6234 - accuracy: 0.9217 - val_loss: 0.6925 - val_accuracy: 0.5109
# Epoch 14/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6208 - accuracy: 0.9271 - val_loss: 0.6921 - val_accuracy: 0.5036
# Epoch 15/100
# 9/9 [==============================] - 8s 878ms/step - loss: 0.6189 - accuracy: 0.9308 - val_loss: 0.6917 - val_accuracy: 0.4891
# Epoch 16/100
# 9/9 [==============================] - 8s 861ms/step - loss: 0.6185 - accuracy: 0.9271 - val_loss: 0.6923 - val_accuracy: 0.4964
# Epoch 17/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6195 - accuracy: 0.9235 - val_loss: 0.6910 - val_accuracy: 0.5401
# Epoch 18/100
# 9/9 [==============================] - 8s 899ms/step - loss: 0.6141 - accuracy: 0.9417 - val_loss: 0.6901 - val_accuracy: 0.5474
# Epoch 19/100
# 9/9 [==============================] - 8s 855ms/step - loss: 0.6172 - accuracy: 0.9144 - val_loss: 0.6901 - val_accuracy: 0.5547
# Epoch 20/100
# 9/9 [==============================] - 8s 894ms/step - loss: 0.6119 - accuracy: 0.9399 - val_loss: 0.6888 - val_accuracy: 0.5839
# Epoch 21/100
# 9/9 [==============================] - 8s 848ms/step - loss: 0.6156 - accuracy: 0.9180 - val_loss: 0.6891 - val_accuracy: 0.5401
# Epoch 22/100
# 9/9 [==============================] - 8s 890ms/step - loss: 0.6127 - accuracy: 0.9199 - val_loss: 0.6872 - val_accuracy: 0.5474
# Epoch 23/100
# 9/9 [==============================] - 8s 893ms/step - loss: 0.6134 - accuracy: 0.9199 - val_loss: 0.6863 - val_accuracy: 0.5766
# Epoch 24/100
# 9/9 [==============================] - 8s 886ms/step - loss: 0.6131 - accuracy: 0.9217 - val_loss: 0.6779 - val_accuracy: 0.6496
# Epoch 25/100
# 9/9 [==============================] - 8s 879ms/step - loss: 0.6141 - accuracy: 0.9053 - val_loss: 0.6715 - val_accuracy: 0.6715
# Epoch 26/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6114 - accuracy: 0.9016 - val_loss: 0.6711 - val_accuracy: 0.6569
# Epoch 27/100
# 9/9 [==============================] - 8s 909ms/step - loss: 0.6102 - accuracy: 0.9180 - val_loss: 0.6662 - val_accuracy: 0.7007
# Epoch 28/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.6094 - accuracy: 0.9071 - val_loss: 0.6610 - val_accuracy: 0.6934
# Epoch 29/100
# 9/9 [==============================] - 8s 886ms/step - loss: 0.6112 - accuracy: 0.8925 - val_loss: 0.6602 - val_accuracy: 0.6934
# Epoch 30/100
# 9/9 [==============================] - 8s 911ms/step - loss: 0.6103 - accuracy: 0.8907 - val_loss: 0.6515 - val_accuracy: 0.7810
# Epoch 31/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.6100 - accuracy: 0.9126 - val_loss: 0.6410 - val_accuracy: 0.8321
# Epoch 32/100
# 9/9 [==============================] - 8s 902ms/step - loss: 0.6068 - accuracy: 0.9253 - val_loss: 0.6391 - val_accuracy: 0.8248
# Epoch 33/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.6085 - accuracy: 0.9016 - val_loss: 0.6359 - val_accuracy: 0.8686
# Epoch 34/100
# 9/9 [==============================] - 7s 823ms/step - loss: 0.6095 - accuracy: 0.9107 - val_loss: 0.6386 - val_accuracy: 0.8248
# Epoch 35/100
# 9/9 [==============================] - 8s 882ms/step - loss: 0.6070 - accuracy: 0.9071 - val_loss: 0.6400 - val_accuracy: 0.8175
# Epoch 36/100
# 9/9 [==============================] - 8s 872ms/step - loss: 0.6041 - accuracy: 0.9180 - val_loss: 0.6381 - val_accuracy: 0.8321
# Epoch 37/100
# 9/9 [==============================] - 8s 872ms/step - loss: 0.6045 - accuracy: 0.9089 - val_loss: 0.6410 - val_accuracy: 0.8175
# Epoch 38/100
# 9/9 [==============================] - 8s 856ms/step - loss: 0.6047 - accuracy: 0.9199 - val_loss: 0.6429 - val_accuracy: 0.8029
# Epoch 39/100
# 9/9 [==============================] - 8s 861ms/step - loss: 0.6087 - accuracy: 0.9016 - val_loss: 0.6394 - val_accuracy: 0.8175
# Epoch 40/100
# 9/9 [==============================] - 8s 844ms/step - loss: 0.6035 - accuracy: 0.9126 - val_loss: 0.6359 - val_accuracy: 0.8175
# Epoch 41/100
# 9/9 [==============================] - 8s 922ms/step - loss: 0.6035 - accuracy: 0.9144 - val_loss: 0.6299 - val_accuracy: 0.8613
# Epoch 42/100
# 9/9 [==============================] - 8s 927ms/step - loss: 0.6015 - accuracy: 0.9253 - val_loss: 0.6276 - val_accuracy: 0.8540
# Epoch 43/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.6056 - accuracy: 0.8998 - val_loss: 0.6299 - val_accuracy: 0.8540
# Epoch 44/100
# 9/9 [==============================] - 8s 846ms/step - loss: 0.6016 - accuracy: 0.9199 - val_loss: 0.6324 - val_accuracy: 0.8467
# Epoch 45/100
# 9/9 [==============================] - 8s 853ms/step - loss: 0.6025 - accuracy: 0.9053 - val_loss: 0.6327 - val_accuracy: 0.8248
# Epoch 46/100
# 9/9 [==============================] - 8s 878ms/step - loss: 0.6012 - accuracy: 0.9053 - val_loss: 0.6331 - val_accuracy: 0.8248
# Epoch 47/100
# 9/9 [==============================] - 8s 858ms/step - loss: 0.5995 - accuracy: 0.9253 - val_loss: 0.6303 - val_accuracy: 0.8394
# Epoch 48/100
# 9/9 [==============================] - 8s 873ms/step - loss: 0.5998 - accuracy: 0.9107 - val_loss: 0.6308 - val_accuracy: 0.8248
# Epoch 49/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.6016 - accuracy: 0.9144 - val_loss: 0.6288 - val_accuracy: 0.8321
# Epoch 50/100
# 9/9 [==============================] - 8s 868ms/step - loss: 0.6009 - accuracy: 0.8998 - val_loss: 0.6330 - val_accuracy: 0.8175
# Epoch 51/100
# 9/9 [==============================] - 8s 885ms/step - loss: 0.5996 - accuracy: 0.9053 - val_loss: 0.6286 - val_accuracy: 0.8540
# Epoch 52/100
# 9/9 [==============================] - 8s 944ms/step - loss: 0.5982 - accuracy: 0.9180 - val_loss: 0.6256 - val_accuracy: 0.8540
# Epoch 53/100
# 9/9 [==============================] - 8s 855ms/step - loss: 0.5930 - accuracy: 0.9381 - val_loss: 0.6273 - val_accuracy: 0.8394
# Epoch 54/100
# 9/9 [==============================] - 8s 855ms/step - loss: 0.5994 - accuracy: 0.9217 - val_loss: 0.6306 - val_accuracy: 0.8175
# Epoch 55/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.5972 - accuracy: 0.9126 - val_loss: 0.6314 - val_accuracy: 0.8175
# Epoch 56/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.5959 - accuracy: 0.9235 - val_loss: 0.6303 - val_accuracy: 0.8248
# Epoch 57/100
# 9/9 [==============================] - 8s 888ms/step - loss: 0.5996 - accuracy: 0.9071 - val_loss: 0.6254 - val_accuracy: 0.8467
# Epoch 58/100
# 9/9 [==============================] - 8s 888ms/step - loss: 0.5968 - accuracy: 0.9217 - val_loss: 0.6214 - val_accuracy: 0.8613
# Epoch 59/100
# 9/9 [==============================] - 8s 938ms/step - loss: 0.5932 - accuracy: 0.9180 - val_loss: 0.6143 - val_accuracy: 0.8905
# Epoch 60/100
# 9/9 [==============================] - 8s 856ms/step - loss: 0.5937 - accuracy: 0.9071 - val_loss: 0.6178 - val_accuracy: 0.8905
# Epoch 61/100
# 9/9 [==============================] - 8s 842ms/step - loss: 0.5917 - accuracy: 0.9290 - val_loss: 0.6185 - val_accuracy: 0.8686
# Epoch 62/100
# 9/9 [==============================] - 8s 861ms/step - loss: 0.5939 - accuracy: 0.9071 - val_loss: 0.6254 - val_accuracy: 0.8394
# Epoch 63/100
# 9/9 [==============================] - 8s 875ms/step - loss: 0.5909 - accuracy: 0.9180 - val_loss: 0.6232 - val_accuracy: 0.8540
# Epoch 64/100
# 9/9 [==============================] - 8s 856ms/step - loss: 0.5945 - accuracy: 0.9016 - val_loss: 0.6154 - val_accuracy: 0.8832
# Epoch 65/100
# 9/9 [==============================] - 8s 896ms/step - loss: 0.5901 - accuracy: 0.9308 - val_loss: 0.6114 - val_accuracy: 0.9051
# Epoch 66/100
# 9/9 [==============================] - 8s 851ms/step - loss: 0.5956 - accuracy: 0.9199 - val_loss: 0.6121 - val_accuracy: 0.8978
# Epoch 67/100
# 9/9 [==============================] - 8s 864ms/step - loss: 0.5908 - accuracy: 0.9071 - val_loss: 0.6126 - val_accuracy: 0.8905
# Epoch 68/100
# 9/9 [==============================] - 8s 857ms/step - loss: 0.5952 - accuracy: 0.9144 - val_loss: 0.6120 - val_accuracy: 0.8832
# Epoch 69/100
# 9/9 [==============================] - 8s 845ms/step - loss: 0.5917 - accuracy: 0.9144 - val_loss: 0.6132 - val_accuracy: 0.8832
# Epoch 70/100
# 9/9 [==============================] - 8s 839ms/step - loss: 0.5929 - accuracy: 0.9071 - val_loss: 0.6121 - val_accuracy: 0.8832
# Epoch 71/100
# 9/9 [==============================] - 8s 868ms/step - loss: 0.5901 - accuracy: 0.9144 - val_loss: 0.6140 - val_accuracy: 0.8759
# Epoch 72/100
# 9/9 [==============================] - 8s 909ms/step - loss: 0.5957 - accuracy: 0.9035 - val_loss: 0.6096 - val_accuracy: 0.8978
# Epoch 73/100
# 9/9 [==============================] - 7s 821ms/step - loss: 0.5944 - accuracy: 0.8925 - val_loss: 0.6210 - val_accuracy: 0.8394
# Epoch 74/100
# 9/9 [==============================] - 7s 810ms/step - loss: 0.5895 - accuracy: 0.8962 - val_loss: 0.6213 - val_accuracy: 0.8321
# Epoch 75/100
# 9/9 [==============================] - 8s 857ms/step - loss: 0.5897 - accuracy: 0.9089 - val_loss: 0.6187 - val_accuracy: 0.8613
# Epoch 76/100
# 9/9 [==============================] - 8s 861ms/step - loss: 0.5860 - accuracy: 0.9180 - val_loss: 0.6150 - val_accuracy: 0.8686
# Epoch 77/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5895 - accuracy: 0.9107 - val_loss: 0.6121 - val_accuracy: 0.8759
# Epoch 78/100
# 9/9 [==============================] - 8s 882ms/step - loss: 0.5928 - accuracy: 0.8944 - val_loss: 0.6101 - val_accuracy: 0.8832
# Epoch 79/100
# 9/9 [==============================] - 7s 832ms/step - loss: 0.5887 - accuracy: 0.9089 - val_loss: 0.6107 - val_accuracy: 0.8686
# Epoch 80/100
# 9/9 [==============================] - 7s 810ms/step - loss: 0.5901 - accuracy: 0.9089 - val_loss: 0.6242 - val_accuracy: 0.8248
# Epoch 81/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.5891 - accuracy: 0.8925 - val_loss: 0.6326 - val_accuracy: 0.7737
# Epoch 82/100
# 9/9 [==============================] - 8s 853ms/step - loss: 0.5846 - accuracy: 0.9126 - val_loss: 0.6330 - val_accuracy: 0.7664
# Epoch 83/100
# 9/9 [==============================] - 8s 856ms/step - loss: 0.5830 - accuracy: 0.9253 - val_loss: 0.6215 - val_accuracy: 0.8321
# Epoch 84/100
# 9/9 [==============================] - 8s 849ms/step - loss: 0.5867 - accuracy: 0.9089 - val_loss: 0.6181 - val_accuracy: 0.8467
# Epoch 85/100
# 9/9 [==============================] - 8s 852ms/step - loss: 0.5876 - accuracy: 0.8962 - val_loss: 0.6157 - val_accuracy: 0.8540
# Epoch 86/100
# 9/9 [==============================] - 8s 909ms/step - loss: 0.5816 - accuracy: 0.9344 - val_loss: 0.6091 - val_accuracy: 0.8832
# Epoch 87/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.5806 - accuracy: 0.9217 - val_loss: 0.6065 - val_accuracy: 0.8905
# Epoch 88/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.5835 - accuracy: 0.9035 - val_loss: 0.6046 - val_accuracy: 0.8978
# Epoch 89/100
# 9/9 [==============================] - 8s 843ms/step - loss: 0.5821 - accuracy: 0.9162 - val_loss: 0.6049 - val_accuracy: 0.8978
# Epoch 90/100
# 9/9 [==============================] - 8s 837ms/step - loss: 0.5832 - accuracy: 0.9217 - val_loss: 0.6061 - val_accuracy: 0.8905
# Epoch 91/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5834 - accuracy: 0.9089 - val_loss: 0.6106 - val_accuracy: 0.8686
# Epoch 92/100
# 9/9 [==============================] - 8s 847ms/step - loss: 0.5815 - accuracy: 0.9199 - val_loss: 0.6061 - val_accuracy: 0.8832
# Epoch 93/100
# 9/9 [==============================] - 8s 922ms/step - loss: 0.5821 - accuracy: 0.9290 - val_loss: 0.6020 - val_accuracy: 0.9051
# Epoch 94/100
# 9/9 [==============================] - 8s 911ms/step - loss: 0.5819 - accuracy: 0.9107 - val_loss: 0.6010 - val_accuracy: 0.9051
# Epoch 95/100
# 9/9 [==============================] - 8s 932ms/step - loss: 0.5787 - accuracy: 0.9253 - val_loss: 0.5989 - val_accuracy: 0.9051
# Epoch 96/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.5836 - accuracy: 0.9035 - val_loss: 0.5972 - val_accuracy: 0.9124
# Epoch 97/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.5799 - accuracy: 0.9180 - val_loss: 0.5998 - val_accuracy: 0.8978
# Epoch 98/100
# 9/9 [==============================] - 8s 845ms/step - loss: 0.5833 - accuracy: 0.8871 - val_loss: 0.6171 - val_accuracy: 0.8175
# Epoch 99/100
# 9/9 [==============================] - 8s 859ms/step - loss: 0.5778 - accuracy: 0.9235 - val_loss: 0.6063 - val_accuracy: 0.8832
# Epoch 100/100
# 9/9 [==============================] - 8s 854ms/step - loss: 0.5788 - accuracy: 0.9271 - val_loss: 0.6156 - val_accuracy: 0.8248
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.
# mobE0
# Epoch 1/2
# 9/9 [==============================] - 6s 654ms/step - loss: 0.6917 - accuracy: 0.6157 - val_loss: 0.6933 - val_accuracy: 0.4672
# Epoch 2/2
# 9/9 [==============================] - 5s 553ms/step - loss: 0.6915 - accuracy: 0.6102 - val_loss: 0.6932 - val_accuracy: 0.4745
# Epoch 1/100
# 2/9 [=====>........................] - ETA: 1s - loss: 0.6911 - accuracy: 0.6562WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1261s vs `on_train_batch_end` time: 0.3372s). Check your callbacks.
# 9/9 [==============================] - 9s 1s/step - loss: 0.6823 - accuracy: 0.8415 - val_loss: 0.6824 - val_accuracy: 0.9781
# Epoch 2/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.6595 - accuracy: 0.9727 - val_loss: 0.6699 - val_accuracy: 0.9635
# Epoch 3/100
# 9/9 [==============================] - 8s 873ms/step - loss: 0.6469 - accuracy: 0.9781 - val_loss: 0.6599 - val_accuracy: 0.9708
# Epoch 4/100
# 9/9 [==============================] - 8s 915ms/step - loss: 0.6388 - accuracy: 0.9854 - val_loss: 0.6535 - val_accuracy: 0.9708
# Epoch 5/100
# 9/9 [==============================] - 8s 859ms/step - loss: 0.6336 - accuracy: 0.9927 - val_loss: 0.6494 - val_accuracy: 0.9708
# Epoch 6/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6269 - accuracy: 0.9891 - val_loss: 0.6458 - val_accuracy: 0.9708
# Epoch 7/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.6256 - accuracy: 0.9636 - val_loss: 0.6428 - val_accuracy: 0.9708
# Epoch 8/100
# 9/9 [==============================] - 8s 919ms/step - loss: 0.6268 - accuracy: 0.9563 - val_loss: 0.6404 - val_accuracy: 0.9708
# Epoch 9/100
# 9/9 [==============================] - 8s 919ms/step - loss: 0.6245 - accuracy: 0.9581 - val_loss: 0.6381 - val_accuracy: 0.9708
# Epoch 10/100
# 9/9 [==============================] - 8s 918ms/step - loss: 0.6235 - accuracy: 0.9381 - val_loss: 0.6345 - val_accuracy: 0.9708
# Epoch 11/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.6213 - accuracy: 0.9399 - val_loss: 0.6316 - val_accuracy: 0.9854
# Epoch 12/100
# 9/9 [==============================] - 8s 870ms/step - loss: 0.6203 - accuracy: 0.9290 - val_loss: 0.6281 - val_accuracy: 0.9781
# Epoch 13/100
# 9/9 [==============================] - 8s 896ms/step - loss: 0.6209 - accuracy: 0.9126 - val_loss: 0.6278 - val_accuracy: 0.9781
# Epoch 14/100
# 9/9 [==============================] - 8s 907ms/step - loss: 0.6193 - accuracy: 0.9180 - val_loss: 0.6269 - val_accuracy: 0.9781
# Epoch 15/100
# 9/9 [==============================] - 8s 917ms/step - loss: 0.6194 - accuracy: 0.9199 - val_loss: 0.6258 - val_accuracy: 0.9781
# Epoch 16/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.6154 - accuracy: 0.9271 - val_loss: 0.6239 - val_accuracy: 0.9781
# Epoch 17/100
# 9/9 [==============================] - 8s 886ms/step - loss: 0.6135 - accuracy: 0.9271 - val_loss: 0.6209 - val_accuracy: 0.9781
# Epoch 18/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.6153 - accuracy: 0.9035 - val_loss: 0.6206 - val_accuracy: 0.9708
# Epoch 19/100
# 9/9 [==============================] - 8s 891ms/step - loss: 0.6136 - accuracy: 0.9162 - val_loss: 0.6190 - val_accuracy: 0.9781
# Epoch 20/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.6099 - accuracy: 0.9235 - val_loss: 0.6160 - val_accuracy: 0.9781
# Epoch 21/100
# 9/9 [==============================] - 8s 907ms/step - loss: 0.6121 - accuracy: 0.9235 - val_loss: 0.6147 - val_accuracy: 0.9708
# Epoch 22/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.6104 - accuracy: 0.9089 - val_loss: 0.6139 - val_accuracy: 0.9781
# Epoch 23/100
# 9/9 [==============================] - 8s 901ms/step - loss: 0.6129 - accuracy: 0.8962 - val_loss: 0.6130 - val_accuracy: 0.9708
# Epoch 24/100
# 9/9 [==============================] - 8s 899ms/step - loss: 0.6086 - accuracy: 0.9290 - val_loss: 0.6122 - val_accuracy: 0.9781
# Epoch 25/100
# 9/9 [==============================] - 8s 903ms/step - loss: 0.6078 - accuracy: 0.9071 - val_loss: 0.6118 - val_accuracy: 0.9708
# Epoch 26/100
# 9/9 [==============================] - 8s 899ms/step - loss: 0.6089 - accuracy: 0.9344 - val_loss: 0.6108 - val_accuracy: 0.9781
# Epoch 27/100
# 9/9 [==============================] - 8s 911ms/step - loss: 0.6085 - accuracy: 0.9180 - val_loss: 0.6088 - val_accuracy: 0.9854
# Epoch 28/100
# 9/9 [==============================] - 8s 847ms/step - loss: 0.6087 - accuracy: 0.9235 - val_loss: 0.6119 - val_accuracy: 0.9635
# Epoch 29/100
# 9/9 [==============================] - 8s 897ms/step - loss: 0.6070 - accuracy: 0.9089 - val_loss: 0.6086 - val_accuracy: 0.9781
# Epoch 30/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.6059 - accuracy: 0.9053 - val_loss: 0.6080 - val_accuracy: 0.9781
# Epoch 31/100
# 9/9 [==============================] - 8s 905ms/step - loss: 0.6108 - accuracy: 0.8962 - val_loss: 0.6074 - val_accuracy: 0.9781
# Epoch 32/100
# 9/9 [==============================] - 8s 893ms/step - loss: 0.6076 - accuracy: 0.9235 - val_loss: 0.6070 - val_accuracy: 0.9781
# Epoch 33/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.6052 - accuracy: 0.9035 - val_loss: 0.6066 - val_accuracy: 0.9708
# Epoch 34/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.6064 - accuracy: 0.9126 - val_loss: 0.6066 - val_accuracy: 0.9781
# Epoch 35/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6079 - accuracy: 0.8962 - val_loss: 0.6065 - val_accuracy: 0.9708
# Epoch 36/100
# 9/9 [==============================] - 8s 873ms/step - loss: 0.6065 - accuracy: 0.8925 - val_loss: 0.6073 - val_accuracy: 0.9708
# Epoch 37/100
# 9/9 [==============================] - 8s 855ms/step - loss: 0.6073 - accuracy: 0.8871 - val_loss: 0.6084 - val_accuracy: 0.9562
# Epoch 38/100
# 9/9 [==============================] - 8s 898ms/step - loss: 0.6054 - accuracy: 0.9107 - val_loss: 0.6064 - val_accuracy: 0.9708
# Epoch 39/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6018 - accuracy: 0.9126 - val_loss: 0.6068 - val_accuracy: 0.9635
# Epoch 40/100
# 9/9 [==============================] - 8s 920ms/step - loss: 0.6062 - accuracy: 0.9016 - val_loss: 0.6063 - val_accuracy: 0.9635
# Epoch 41/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5995 - accuracy: 0.9144 - val_loss: 0.6066 - val_accuracy: 0.9635
# Epoch 42/100
# 9/9 [==============================] - 8s 917ms/step - loss: 0.6004 - accuracy: 0.9253 - val_loss: 0.6055 - val_accuracy: 0.9635
# Epoch 43/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6005 - accuracy: 0.9107 - val_loss: 0.6043 - val_accuracy: 0.9708
# Epoch 44/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.5973 - accuracy: 0.9271 - val_loss: 0.6037 - val_accuracy: 0.9708
# Epoch 45/100
# 9/9 [==============================] - 8s 888ms/step - loss: 0.5989 - accuracy: 0.9253 - val_loss: 0.6028 - val_accuracy: 0.9635
# Epoch 46/100
# 9/9 [==============================] - 8s 859ms/step - loss: 0.6019 - accuracy: 0.8944 - val_loss: 0.6031 - val_accuracy: 0.9562
# Epoch 47/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.6004 - accuracy: 0.9107 - val_loss: 0.6156 - val_accuracy: 0.8905
# Epoch 48/100
# 9/9 [==============================] - 8s 865ms/step - loss: 0.6027 - accuracy: 0.8962 - val_loss: 0.6160 - val_accuracy: 0.8905
# Epoch 49/100
# 9/9 [==============================] - 8s 842ms/step - loss: 0.5989 - accuracy: 0.9162 - val_loss: 0.6198 - val_accuracy: 0.8832
# Epoch 50/100
# 9/9 [==============================] - 8s 868ms/step - loss: 0.5978 - accuracy: 0.9071 - val_loss: 0.6185 - val_accuracy: 0.8759
# Epoch 51/100
# 9/9 [==============================] - 8s 853ms/step - loss: 0.5938 - accuracy: 0.9271 - val_loss: 0.6070 - val_accuracy: 0.9343
# Epoch 52/100
# 9/9 [==============================] - 8s 876ms/step - loss: 0.5989 - accuracy: 0.9144 - val_loss: 0.6032 - val_accuracy: 0.9562
# Epoch 53/100
# 9/9 [==============================] - 8s 918ms/step - loss: 0.5972 - accuracy: 0.8980 - val_loss: 0.6005 - val_accuracy: 0.9635
# Epoch 54/100
# 9/9 [==============================] - 8s 897ms/step - loss: 0.5966 - accuracy: 0.9144 - val_loss: 0.5981 - val_accuracy: 0.9708
# Epoch 55/100
# 9/9 [==============================] - 8s 906ms/step - loss: 0.5963 - accuracy: 0.9071 - val_loss: 0.5972 - val_accuracy: 0.9708
# Epoch 56/100
# 9/9 [==============================] - 8s 880ms/step - loss: 0.5965 - accuracy: 0.9089 - val_loss: 0.5967 - val_accuracy: 0.9708
# Epoch 57/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.5914 - accuracy: 0.9126 - val_loss: 0.5962 - val_accuracy: 0.9708
# Epoch 58/100
# 9/9 [==============================] - 8s 863ms/step - loss: 0.5941 - accuracy: 0.9089 - val_loss: 0.5965 - val_accuracy: 0.9708
# Epoch 59/100
# 9/9 [==============================] - 8s 890ms/step - loss: 0.5934 - accuracy: 0.9235 - val_loss: 0.5956 - val_accuracy: 0.9708
# Epoch 60/100
# 9/9 [==============================] - 7s 827ms/step - loss: 0.5945 - accuracy: 0.9162 - val_loss: 0.5959 - val_accuracy: 0.9708
# Epoch 61/100
# 9/9 [==============================] - 8s 864ms/step - loss: 0.5928 - accuracy: 0.9053 - val_loss: 0.5992 - val_accuracy: 0.9562
# Epoch 62/100
# 9/9 [==============================] - 7s 831ms/step - loss: 0.5906 - accuracy: 0.9144 - val_loss: 0.6003 - val_accuracy: 0.9416
# Epoch 63/100
# 9/9 [==============================] - 8s 907ms/step - loss: 0.5932 - accuracy: 0.9016 - val_loss: 0.5954 - val_accuracy: 0.9708
# Epoch 64/100
# 9/9 [==============================] - 8s 890ms/step - loss: 0.5956 - accuracy: 0.9016 - val_loss: 0.5953 - val_accuracy: 0.9635
# Epoch 65/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.5957 - accuracy: 0.8907 - val_loss: 0.5939 - val_accuracy: 0.9635
# Epoch 66/100
# 9/9 [==============================] - 8s 863ms/step - loss: 0.5898 - accuracy: 0.9199 - val_loss: 0.5939 - val_accuracy: 0.9635
# Epoch 67/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5865 - accuracy: 0.9326 - val_loss: 0.5964 - val_accuracy: 0.9489
# Epoch 68/100
# 9/9 [==============================] - 8s 865ms/step - loss: 0.5915 - accuracy: 0.9199 - val_loss: 0.5957 - val_accuracy: 0.9489
# Epoch 69/100
# 9/9 [==============================] - 8s 857ms/step - loss: 0.5946 - accuracy: 0.8980 - val_loss: 0.5941 - val_accuracy: 0.9562
# Epoch 70/100
# 9/9 [==============================] - 8s 872ms/step - loss: 0.5911 - accuracy: 0.9053 - val_loss: 0.5941 - val_accuracy: 0.9562
# Epoch 71/100
# 9/9 [==============================] - 8s 873ms/step - loss: 0.5906 - accuracy: 0.9107 - val_loss: 0.5946 - val_accuracy: 0.9562
# Epoch 72/100
# 9/9 [==============================] - 8s 911ms/step - loss: 0.5903 - accuracy: 0.8944 - val_loss: 0.5938 - val_accuracy: 0.9562
# Epoch 73/100
# 9/9 [==============================] - 8s 905ms/step - loss: 0.5870 - accuracy: 0.9144 - val_loss: 0.5920 - val_accuracy: 0.9635
# Epoch 74/100
# 9/9 [==============================] - 8s 917ms/step - loss: 0.5891 - accuracy: 0.9144 - val_loss: 0.5913 - val_accuracy: 0.9635
# Epoch 75/100
# 9/9 [==============================] - 8s 858ms/step - loss: 0.5893 - accuracy: 0.9053 - val_loss: 0.5995 - val_accuracy: 0.9270
# Epoch 76/100
# 9/9 [==============================] - 8s 903ms/step - loss: 0.5877 - accuracy: 0.9016 - val_loss: 0.5898 - val_accuracy: 0.9635
# Epoch 77/100
# 9/9 [==============================] - 8s 863ms/step - loss: 0.5874 - accuracy: 0.9107 - val_loss: 0.5900 - val_accuracy: 0.9635
# Epoch 78/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.5881 - accuracy: 0.8998 - val_loss: 0.5877 - val_accuracy: 0.9708
# Epoch 79/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.5842 - accuracy: 0.9290 - val_loss: 0.5864 - val_accuracy: 0.9781
# Epoch 80/100
# 9/9 [==============================] - 8s 848ms/step - loss: 0.5839 - accuracy: 0.9253 - val_loss: 0.5865 - val_accuracy: 0.9708
# Epoch 81/100
# 9/9 [==============================] - 8s 842ms/step - loss: 0.5859 - accuracy: 0.9035 - val_loss: 0.5901 - val_accuracy: 0.9562
# Epoch 82/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.5835 - accuracy: 0.9180 - val_loss: 0.5896 - val_accuracy: 0.9562
# Epoch 83/100
# 9/9 [==============================] - 8s 896ms/step - loss: 0.5855 - accuracy: 0.9016 - val_loss: 0.5871 - val_accuracy: 0.9635
# Epoch 84/100
# 9/9 [==============================] - 8s 893ms/step - loss: 0.5832 - accuracy: 0.9053 - val_loss: 0.5860 - val_accuracy: 0.9708
# Epoch 85/100
# 9/9 [==============================] - 9s 945ms/step - loss: 0.5800 - accuracy: 0.9217 - val_loss: 0.5847 - val_accuracy: 0.9708
# Epoch 86/100
# 9/9 [==============================] - 8s 887ms/step - loss: 0.5797 - accuracy: 0.9271 - val_loss: 0.5827 - val_accuracy: 0.9781
# Epoch 87/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.5818 - accuracy: 0.8998 - val_loss: 0.5828 - val_accuracy: 0.9781
# Epoch 88/100
# 9/9 [==============================] - 8s 875ms/step - loss: 0.5794 - accuracy: 0.9053 - val_loss: 0.5839 - val_accuracy: 0.9708
# Epoch 89/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.5799 - accuracy: 0.9126 - val_loss: 0.5838 - val_accuracy: 0.9635
# Epoch 90/100
# 9/9 [==============================] - 8s 874ms/step - loss: 0.5809 - accuracy: 0.9271 - val_loss: 0.5843 - val_accuracy: 0.9635
# Epoch 91/100
# 9/9 [==============================] - 8s 844ms/step - loss: 0.5817 - accuracy: 0.9053 - val_loss: 0.5872 - val_accuracy: 0.9489
# Epoch 92/100
# 9/9 [==============================] - 8s 850ms/step - loss: 0.5754 - accuracy: 0.9417 - val_loss: 0.5868 - val_accuracy: 0.9489
# Epoch 93/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5800 - accuracy: 0.9144 - val_loss: 0.5859 - val_accuracy: 0.9489
# Epoch 94/100
# 9/9 [==============================] - 8s 857ms/step - loss: 0.5812 - accuracy: 0.9071 - val_loss: 0.5845 - val_accuracy: 0.9562
# Epoch 95/100
# 9/9 [==============================] - 8s 884ms/step - loss: 0.5802 - accuracy: 0.9144 - val_loss: 0.5840 - val_accuracy: 0.9562
# Epoch 96/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.5787 - accuracy: 0.9253 - val_loss: 0.5824 - val_accuracy: 0.9635
# Epoch 97/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.5810 - accuracy: 0.8980 - val_loss: 0.5814 - val_accuracy: 0.9635
# Epoch 98/100
# 9/9 [==============================] - 8s 905ms/step - loss: 0.5765 - accuracy: 0.9199 - val_loss: 0.5810 - val_accuracy: 0.9635
# Epoch 99/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.5774 - accuracy: 0.9126 - val_loss: 0.5806 - val_accuracy: 0.9635
# Epoch 100/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.5765 - accuracy: 0.9217 - val_loss: 0.5801 - val_accuracy: 0.9635
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.
# mobE0
# Epoch 1/2
# 9/9 [==============================] - 6s 652ms/step - loss: 0.6912 - accuracy: 0.6448 - val_loss: 0.6916 - val_accuracy: 0.8905
# Epoch 2/2
# 9/9 [==============================] - 5s 569ms/step - loss: 0.6909 - accuracy: 0.6539 - val_loss: 0.6915 - val_accuracy: 0.8978
# Epoch 1/100
# 2/9 [=====>........................] - ETA: 1s - loss: 0.6890 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1282s vs `on_train_batch_end` time: 0.3419s). Check your callbacks.
# 9/9 [==============================] - 9s 967ms/step - loss: 0.6780 - accuracy: 0.9271 - val_loss: 0.6799 - val_accuracy: 0.9854
# Epoch 2/100
# 9/9 [==============================] - 8s 902ms/step - loss: 0.6535 - accuracy: 0.9909 - val_loss: 0.6680 - val_accuracy: 0.9854
# Epoch 3/100
# 9/9 [==============================] - 8s 884ms/step - loss: 0.6391 - accuracy: 0.9800 - val_loss: 0.6557 - val_accuracy: 0.9854
# Epoch 4/100
# 9/9 [==============================] - 8s 878ms/step - loss: 0.6271 - accuracy: 0.9800 - val_loss: 0.6472 - val_accuracy: 0.9781
# Epoch 5/100
# 9/9 [==============================] - 8s 898ms/step - loss: 0.6275 - accuracy: 0.9253 - val_loss: 0.6437 - val_accuracy: 0.9708
# Epoch 6/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6234 - accuracy: 0.9253 - val_loss: 0.6399 - val_accuracy: 0.9854
# Epoch 7/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.6228 - accuracy: 0.9180 - val_loss: 0.6363 - val_accuracy: 0.9854
# Epoch 8/100
# 9/9 [==============================] - 8s 934ms/step - loss: 0.6206 - accuracy: 0.9381 - val_loss: 0.6326 - val_accuracy: 0.9854
# Epoch 9/100
# 9/9 [==============================] - 8s 937ms/step - loss: 0.6195 - accuracy: 0.9162 - val_loss: 0.6270 - val_accuracy: 1.0000
# Epoch 10/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.6168 - accuracy: 0.9217 - val_loss: 0.6238 - val_accuracy: 1.0000
# Epoch 11/100
# 9/9 [==============================] - 8s 934ms/step - loss: 0.6159 - accuracy: 0.9235 - val_loss: 0.6206 - val_accuracy: 1.0000
# Epoch 12/100
# 9/9 [==============================] - 8s 889ms/step - loss: 0.6184 - accuracy: 0.9144 - val_loss: 0.6190 - val_accuracy: 1.0000
# Epoch 13/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6175 - accuracy: 0.8980 - val_loss: 0.6178 - val_accuracy: 1.0000
# Epoch 14/100
# 9/9 [==============================] - 8s 942ms/step - loss: 0.6135 - accuracy: 0.9235 - val_loss: 0.6164 - val_accuracy: 1.0000
# Epoch 15/100
# 9/9 [==============================] - 8s 932ms/step - loss: 0.6153 - accuracy: 0.9053 - val_loss: 0.6147 - val_accuracy: 1.0000
# Epoch 16/100
# 9/9 [==============================] - 8s 924ms/step - loss: 0.6119 - accuracy: 0.9253 - val_loss: 0.6137 - val_accuracy: 1.0000
# Epoch 17/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.6118 - accuracy: 0.9107 - val_loss: 0.6131 - val_accuracy: 1.0000
# Epoch 18/100
# 9/9 [==============================] - 8s 915ms/step - loss: 0.6135 - accuracy: 0.9089 - val_loss: 0.6117 - val_accuracy: 1.0000
# Epoch 19/100
# 9/9 [==============================] - 8s 943ms/step - loss: 0.6118 - accuracy: 0.9162 - val_loss: 0.6108 - val_accuracy: 1.0000
# Epoch 20/100
# 9/9 [==============================] - 8s 943ms/step - loss: 0.6129 - accuracy: 0.9071 - val_loss: 0.6102 - val_accuracy: 1.0000
# Epoch 21/100
# 9/9 [==============================] - 8s 885ms/step - loss: 0.6096 - accuracy: 0.9126 - val_loss: 0.6096 - val_accuracy: 1.0000
# Epoch 22/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6106 - accuracy: 0.9399 - val_loss: 0.6087 - val_accuracy: 1.0000
# Epoch 23/100
# 9/9 [==============================] - 7s 805ms/step - loss: 0.6127 - accuracy: 0.9180 - val_loss: 0.6088 - val_accuracy: 1.0000
# Epoch 24/100
# 9/9 [==============================] - 8s 915ms/step - loss: 0.6121 - accuracy: 0.9271 - val_loss: 0.6084 - val_accuracy: 1.0000
# Epoch 25/100
# 9/9 [==============================] - 8s 862ms/step - loss: 0.6087 - accuracy: 0.9035 - val_loss: 0.6176 - val_accuracy: 0.9270
# Epoch 26/100
# 9/9 [==============================] - 9s 950ms/step - loss: 0.6101 - accuracy: 0.9180 - val_loss: 0.6076 - val_accuracy: 1.0000
# Epoch 27/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6098 - accuracy: 0.8998 - val_loss: 0.6095 - val_accuracy: 0.9854
# Epoch 28/100
# 9/9 [==============================] - 8s 858ms/step - loss: 0.6084 - accuracy: 0.9199 - val_loss: 0.6088 - val_accuracy: 0.9854
# Epoch 29/100
# 9/9 [==============================] - 8s 891ms/step - loss: 0.6097 - accuracy: 0.9126 - val_loss: 0.6064 - val_accuracy: 0.9927
# Epoch 30/100
# 9/9 [==============================] - 8s 889ms/step - loss: 0.6092 - accuracy: 0.9071 - val_loss: 0.6049 - val_accuracy: 1.0000
# Epoch 31/100
# 9/9 [==============================] - 8s 841ms/step - loss: 0.6064 - accuracy: 0.9199 - val_loss: 0.6057 - val_accuracy: 0.9927
# Epoch 32/100
# 9/9 [==============================] - 8s 837ms/step - loss: 0.6072 - accuracy: 0.8980 - val_loss: 0.6051 - val_accuracy: 0.9927
# Epoch 33/100
# 9/9 [==============================] - 8s 898ms/step - loss: 0.6071 - accuracy: 0.9053 - val_loss: 0.6048 - val_accuracy: 0.9854
# Epoch 34/100
# 9/9 [==============================] - 8s 927ms/step - loss: 0.6054 - accuracy: 0.9053 - val_loss: 0.6043 - val_accuracy: 0.9927
# Epoch 35/100
# 9/9 [==============================] - 8s 870ms/step - loss: 0.6083 - accuracy: 0.9035 - val_loss: 0.6038 - val_accuracy: 0.9927
# Epoch 36/100
# 9/9 [==============================] - 8s 922ms/step - loss: 0.6035 - accuracy: 0.9217 - val_loss: 0.6029 - val_accuracy: 1.0000
# Epoch 37/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.6015 - accuracy: 0.9472 - val_loss: 0.6025 - val_accuracy: 0.9927
# Epoch 38/100
# 9/9 [==============================] - 8s 893ms/step - loss: 0.6021 - accuracy: 0.9126 - val_loss: 0.6020 - val_accuracy: 0.9927
# Epoch 39/100
# 9/9 [==============================] - 8s 905ms/step - loss: 0.6036 - accuracy: 0.9035 - val_loss: 0.6019 - val_accuracy: 0.9927
# Epoch 40/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6011 - accuracy: 0.9417 - val_loss: 0.6014 - val_accuracy: 0.9927
# Epoch 41/100
# 9/9 [==============================] - 8s 888ms/step - loss: 0.6026 - accuracy: 0.9089 - val_loss: 0.6010 - val_accuracy: 0.9927
# Epoch 42/100
# 9/9 [==============================] - 8s 851ms/step - loss: 0.6025 - accuracy: 0.9126 - val_loss: 0.6014 - val_accuracy: 0.9854
# Epoch 43/100
# 9/9 [==============================] - 8s 903ms/step - loss: 0.6023 - accuracy: 0.9089 - val_loss: 0.6002 - val_accuracy: 0.9927
# Epoch 44/100
# 9/9 [==============================] - 8s 884ms/step - loss: 0.6013 - accuracy: 0.9144 - val_loss: 0.5998 - val_accuracy: 0.9927
# Epoch 45/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.6028 - accuracy: 0.9053 - val_loss: 0.5993 - val_accuracy: 0.9927
# Epoch 46/100
# 9/9 [==============================] - 8s 866ms/step - loss: 0.6000 - accuracy: 0.9199 - val_loss: 0.6000 - val_accuracy: 0.9854
# Epoch 47/100
# 9/9 [==============================] - 8s 909ms/step - loss: 0.5992 - accuracy: 0.9362 - val_loss: 0.5985 - val_accuracy: 0.9927
# Epoch 48/100
# 9/9 [==============================] - 8s 907ms/step - loss: 0.5944 - accuracy: 0.9417 - val_loss: 0.5979 - val_accuracy: 0.9927
# Epoch 49/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.6018 - accuracy: 0.8944 - val_loss: 0.5979 - val_accuracy: 0.9927
# Epoch 50/100
# 9/9 [==============================] - 8s 845ms/step - loss: 0.6002 - accuracy: 0.9016 - val_loss: 0.6017 - val_accuracy: 0.9708
# Epoch 51/100
# 9/9 [==============================] - 8s 846ms/step - loss: 0.5985 - accuracy: 0.9253 - val_loss: 0.5982 - val_accuracy: 0.9854
# Epoch 52/100
# 9/9 [==============================] - 8s 899ms/step - loss: 0.5971 - accuracy: 0.9071 - val_loss: 0.5970 - val_accuracy: 0.9927
# Epoch 53/100
# 9/9 [==============================] - 8s 843ms/step - loss: 0.5946 - accuracy: 0.9271 - val_loss: 0.5974 - val_accuracy: 0.9854
# Epoch 54/100
# 9/9 [==============================] - 8s 909ms/step - loss: 0.5990 - accuracy: 0.9071 - val_loss: 0.5969 - val_accuracy: 0.9854
# Epoch 55/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.5990 - accuracy: 0.9217 - val_loss: 0.5960 - val_accuracy: 0.9854
# Epoch 56/100
# 9/9 [==============================] - 8s 845ms/step - loss: 0.5963 - accuracy: 0.9089 - val_loss: 0.5944 - val_accuracy: 0.9927
# Epoch 57/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.5998 - accuracy: 0.9162 - val_loss: 0.5928 - val_accuracy: 1.0000
# Epoch 58/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.5980 - accuracy: 0.9180 - val_loss: 0.5922 - val_accuracy: 1.0000
# Epoch 59/100
# 9/9 [==============================] - 8s 883ms/step - loss: 0.5939 - accuracy: 0.9290 - val_loss: 0.5918 - val_accuracy: 1.0000
# Epoch 60/100
# 9/9 [==============================] - 8s 932ms/step - loss: 0.5898 - accuracy: 0.9253 - val_loss: 0.5914 - val_accuracy: 1.0000
# Epoch 61/100
# 9/9 [==============================] - 8s 886ms/step - loss: 0.5976 - accuracy: 0.9162 - val_loss: 0.5922 - val_accuracy: 0.9927
# Epoch 62/100
# 9/9 [==============================] - 8s 848ms/step - loss: 0.5975 - accuracy: 0.9144 - val_loss: 0.5924 - val_accuracy: 0.9927
# Epoch 63/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.5934 - accuracy: 0.9271 - val_loss: 0.5913 - val_accuracy: 0.9927
# Epoch 64/100
# 9/9 [==============================] - 8s 917ms/step - loss: 0.5922 - accuracy: 0.9199 - val_loss: 0.5900 - val_accuracy: 1.0000
# Epoch 65/100
# 9/9 [==============================] - 8s 921ms/step - loss: 0.5894 - accuracy: 0.9326 - val_loss: 0.5890 - val_accuracy: 1.0000
# Epoch 66/100
# 9/9 [==============================] - 8s 914ms/step - loss: 0.5949 - accuracy: 0.9089 - val_loss: 0.5886 - val_accuracy: 1.0000
# Epoch 67/100
# 9/9 [==============================] - 8s 923ms/step - loss: 0.5912 - accuracy: 0.9308 - val_loss: 0.5882 - val_accuracy: 1.0000
# Epoch 68/100
# 9/9 [==============================] - 9s 958ms/step - loss: 0.5934 - accuracy: 0.9271 - val_loss: 0.5877 - val_accuracy: 1.0000
# Epoch 69/100
# 9/9 [==============================] - 8s 911ms/step - loss: 0.5867 - accuracy: 0.9399 - val_loss: 0.5873 - val_accuracy: 1.0000
# Epoch 70/100
# 9/9 [==============================] - 8s 931ms/step - loss: 0.5908 - accuracy: 0.9271 - val_loss: 0.5869 - val_accuracy: 1.0000
# Epoch 71/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.5931 - accuracy: 0.8998 - val_loss: 0.5865 - val_accuracy: 1.0000
# Epoch 72/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.5869 - accuracy: 0.9235 - val_loss: 0.5860 - val_accuracy: 1.0000
# Epoch 73/100
# 9/9 [==============================] - 8s 880ms/step - loss: 0.5908 - accuracy: 0.9253 - val_loss: 0.5858 - val_accuracy: 1.0000
# Epoch 74/100
# 9/9 [==============================] - 8s 865ms/step - loss: 0.5911 - accuracy: 0.9126 - val_loss: 0.5865 - val_accuracy: 0.9927
# Epoch 75/100
# 9/9 [==============================] - 8s 884ms/step - loss: 0.5882 - accuracy: 0.9235 - val_loss: 0.5895 - val_accuracy: 0.9781
# Epoch 76/100
# 9/9 [==============================] - 8s 848ms/step - loss: 0.5860 - accuracy: 0.9308 - val_loss: 0.5876 - val_accuracy: 0.9854
# Epoch 77/100
# 9/9 [==============================] - 8s 877ms/step - loss: 0.5864 - accuracy: 0.9344 - val_loss: 0.5839 - val_accuracy: 1.0000
# Epoch 78/100
# 9/9 [==============================] - 8s 858ms/step - loss: 0.5864 - accuracy: 0.9217 - val_loss: 0.5857 - val_accuracy: 0.9927
# Epoch 79/100
# 9/9 [==============================] - 8s 859ms/step - loss: 0.5862 - accuracy: 0.9126 - val_loss: 0.5882 - val_accuracy: 0.9781
# Epoch 80/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5876 - accuracy: 0.9381 - val_loss: 0.5874 - val_accuracy: 0.9781
# Epoch 81/100
# 9/9 [==============================] - 8s 866ms/step - loss: 0.5902 - accuracy: 0.8962 - val_loss: 0.5904 - val_accuracy: 0.9708
# Epoch 82/100
# 9/9 [==============================] - 8s 920ms/step - loss: 0.5870 - accuracy: 0.9107 - val_loss: 0.5828 - val_accuracy: 0.9927
# Epoch 83/100
# 9/9 [==============================] - 8s 852ms/step - loss: 0.5821 - accuracy: 0.9399 - val_loss: 0.5849 - val_accuracy: 0.9854
# Epoch 84/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.5822 - accuracy: 0.9271 - val_loss: 0.5843 - val_accuracy: 0.9854
# Epoch 85/100
# 9/9 [==============================] - 8s 874ms/step - loss: 0.5909 - accuracy: 0.8925 - val_loss: 0.5834 - val_accuracy: 0.9854
# Epoch 86/100
# 9/9 [==============================] - 8s 903ms/step - loss: 0.5855 - accuracy: 0.9199 - val_loss: 0.5809 - val_accuracy: 1.0000
# Epoch 87/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.5833 - accuracy: 0.9235 - val_loss: 0.5800 - val_accuracy: 1.0000
# Epoch 88/100
# 9/9 [==============================] - 8s 856ms/step - loss: 0.5840 - accuracy: 0.9071 - val_loss: 0.5804 - val_accuracy: 0.9927
# Epoch 89/100
# 9/9 [==============================] - 8s 941ms/step - loss: 0.5804 - accuracy: 0.9235 - val_loss: 0.5791 - val_accuracy: 1.0000
# Epoch 90/100
# 9/9 [==============================] - 8s 888ms/step - loss: 0.5778 - accuracy: 0.9454 - val_loss: 0.5787 - val_accuracy: 1.0000
# Epoch 91/100
# 9/9 [==============================] - 8s 900ms/step - loss: 0.5850 - accuracy: 0.9016 - val_loss: 0.5784 - val_accuracy: 1.0000
# Epoch 92/100
# 9/9 [==============================] - 8s 847ms/step - loss: 0.5880 - accuracy: 0.9035 - val_loss: 0.5798 - val_accuracy: 0.9927
# Epoch 93/100
# 9/9 [==============================] - 8s 860ms/step - loss: 0.5829 - accuracy: 0.9016 - val_loss: 0.5795 - val_accuracy: 0.9927
# Epoch 94/100
# 9/9 [==============================] - 8s 885ms/step - loss: 0.5848 - accuracy: 0.9071 - val_loss: 0.5795 - val_accuracy: 0.9927
# Epoch 95/100
# 9/9 [==============================] - 8s 848ms/step - loss: 0.5799 - accuracy: 0.9271 - val_loss: 0.5801 - val_accuracy: 0.9854
# Epoch 96/100
# 9/9 [==============================] - 8s 858ms/step - loss: 0.5864 - accuracy: 0.8798 - val_loss: 0.5792 - val_accuracy: 0.9854
# Epoch 97/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.5838 - accuracy: 0.8944 - val_loss: 0.5789 - val_accuracy: 0.9854
# Epoch 98/100
# 9/9 [==============================] - 8s 885ms/step - loss: 0.5824 - accuracy: 0.9071 - val_loss: 0.5782 - val_accuracy: 0.9854
# Epoch 99/100
# 9/9 [==============================] - 8s 897ms/step - loss: 0.5786 - accuracy: 0.9162 - val_loss: 0.5769 - val_accuracy: 0.9927
# Epoch 100/100
# 9/9 [==============================] - 8s 878ms/step - loss: 0.5800 - accuracy: 0.9235 - val_loss: 0.5765 - val_accuracy: 0.9927
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.
# mobE0
# Epoch 1/2
# 9/9 [==============================] - 6s 653ms/step - loss: 0.6892 - accuracy: 0.6976 - val_loss: 0.6913 - val_accuracy: 0.9270
# Epoch 2/2
# 9/9 [==============================] - 5s 550ms/step - loss: 0.6894 - accuracy: 0.6849 - val_loss: 0.6913 - val_accuracy: 0.9270
# Epoch 1/100
# 2/9 [=====>........................] - ETA: 1s - loss: 0.6876 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1277s vs `on_train_batch_end` time: 0.3204s). Check your callbacks.
# 9/9 [==============================] - 9s 966ms/step - loss: 0.6755 - accuracy: 0.9344 - val_loss: 0.6782 - val_accuracy: 1.0000
# Epoch 2/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.6487 - accuracy: 0.9927 - val_loss: 0.6632 - val_accuracy: 1.0000
# Epoch 3/100
# 9/9 [==============================] - 8s 937ms/step - loss: 0.6323 - accuracy: 0.9927 - val_loss: 0.6514 - val_accuracy: 1.0000
# Epoch 4/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6310 - accuracy: 0.9709 - val_loss: 0.6436 - val_accuracy: 1.0000
# Epoch 5/100
# 9/9 [==============================] - 9s 953ms/step - loss: 0.6246 - accuracy: 0.9490 - val_loss: 0.6374 - val_accuracy: 1.0000
# Epoch 6/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.6202 - accuracy: 0.9308 - val_loss: 0.6331 - val_accuracy: 1.0000
# Epoch 7/100
# 9/9 [==============================] - 8s 906ms/step - loss: 0.6195 - accuracy: 0.9253 - val_loss: 0.6309 - val_accuracy: 1.0000
# Epoch 8/100
# 9/9 [==============================] - 8s 913ms/step - loss: 0.6203 - accuracy: 0.9362 - val_loss: 0.6285 - val_accuracy: 1.0000
# Epoch 9/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6217 - accuracy: 0.9217 - val_loss: 0.6272 - val_accuracy: 0.9927
# Epoch 10/100
# 9/9 [==============================] - 8s 906ms/step - loss: 0.6188 - accuracy: 0.9362 - val_loss: 0.6259 - val_accuracy: 0.9927
# Epoch 11/100
# 9/9 [==============================] - 8s 932ms/step - loss: 0.6207 - accuracy: 0.9144 - val_loss: 0.6240 - val_accuracy: 0.9927
# Epoch 12/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6186 - accuracy: 0.9271 - val_loss: 0.6231 - val_accuracy: 0.9854
# Epoch 13/100
# 9/9 [==============================] - 8s 871ms/step - loss: 0.6180 - accuracy: 0.9126 - val_loss: 0.6251 - val_accuracy: 0.9927
# Epoch 14/100
# 9/9 [==============================] - 8s 891ms/step - loss: 0.6194 - accuracy: 0.9162 - val_loss: 0.6244 - val_accuracy: 0.9854
# Epoch 15/100
# 9/9 [==============================] - 8s 869ms/step - loss: 0.6161 - accuracy: 0.9308 - val_loss: 0.6230 - val_accuracy: 0.9854
# Epoch 16/100
# 9/9 [==============================] - 8s 902ms/step - loss: 0.6193 - accuracy: 0.9053 - val_loss: 0.6193 - val_accuracy: 0.9927
# Epoch 17/100
# 9/9 [==============================] - 8s 938ms/step - loss: 0.6157 - accuracy: 0.9180 - val_loss: 0.6171 - val_accuracy: 1.0000
# Epoch 18/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.6165 - accuracy: 0.9271 - val_loss: 0.6160 - val_accuracy: 1.0000
# Epoch 19/100
# ...
# 9/9 [==============================] - 9s 945ms/step - loss: 0.5824 - accuracy: 0.9253 - val_loss: 0.5834 - val_accuracy: 1.0000
# Epoch 94/100
# 9/9 [==============================] - 9s 945ms/step - loss: 0.5859 - accuracy: 0.9126 - val_loss: 0.5830 - val_accuracy: 1.0000
# Epoch 95/100
# 9/9 [==============================] - 9s 953ms/step - loss: 0.5848 - accuracy: 0.9126 - val_loss: 0.5826 - val_accuracy: 1.0000
# Epoch 96/100
# 9/9 [==============================] - 8s 936ms/step - loss: 0.5880 - accuracy: 0.9126 - val_loss: 0.5822 - val_accuracy: 1.0000
# Epoch 97/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.5854 - accuracy: 0.9308 - val_loss: 0.5818 - val_accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 12s 1s/step - loss: 0.5860 - accuracy: 0.9144 - val_loss: 0.5814 - val_accuracy: 1.0000
# Epoch 99/100
# 9/9 [==============================] - 9s 974ms/step - loss: 0.5810 - accuracy: 0.9217 - val_loss: 0.5810 - val_accuracy: 1.0000
# Epoch 100/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.5860 - accuracy: 0.9126 - val_loss: 0.5806 - val_accuracy: 1.0000
# Found 686 files belonging to 2 classes.
# Using 549 files for training.
# Found 686 files belonging to 2 classes.
# Using 137 files for validation.
# mobE0
# Epoch 1/2
# 9/9 [==============================] - 6s 642ms/step - loss: 0.6925 - accuracy: 0.4608 - val_loss: 0.6930 - val_accuracy: 0.3066
# Epoch 2/2
# 9/9 [==============================] - 5s 568ms/step - loss: 0.6923 - accuracy: 0.4499 - val_loss: 0.6930 - val_accuracy: 0.3139
# Epoch 1/100
# 2/9 [=====>........................] - ETA: 1s - loss: 0.6903 - accuracy: 0.6094WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1287s vs `on_train_batch_end` time: 0.3409s). Check your callbacks.
# 9/9 [==============================] - 9s 1s/step - loss: 0.6749 - accuracy: 0.9089 - val_loss: 0.6725 - val_accuracy: 1.0000
# Epoch 2/100
# 9/9 [==============================] - 8s 938ms/step - loss: 0.6476 - accuracy: 0.9964 - val_loss: 0.6594 - val_accuracy: 1.0000
# Epoch 3/100
# 9/9 [==============================] - 8s 936ms/step - loss: 0.6351 - accuracy: 0.9964 - val_loss: 0.6483 - val_accuracy: 1.0000
# Epoch 4/100
# 9/9 [==============================] - 9s 949ms/step - loss: 0.6290 - accuracy: 0.9690 - val_loss: 0.6398 - val_accuracy: 1.0000
# Epoch 5/100
# 9/9 [==============================] - 8s 927ms/step - loss: 0.6286 - accuracy: 0.9508 - val_loss: 0.6351 - val_accuracy: 1.0000
# Epoch 6/100
# 9/9 [==============================] - 8s 895ms/step - loss: 0.6263 - accuracy: 0.9454 - val_loss: 0.6329 - val_accuracy: 1.0000
# Epoch 7/100
# 9/9 [==============================] - 8s 941ms/step - loss: 0.6230 - accuracy: 0.9563 - val_loss: 0.6290 - val_accuracy: 1.0000
# Epoch 8/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6233 - accuracy: 0.9308 - val_loss: 0.6262 - val_accuracy: 1.0000
# Epoch 9/100
# 9/9 [==============================] - 8s 881ms/step - loss: 0.6223 - accuracy: 0.9271 - val_loss: 0.6246 - val_accuracy: 1.0000
# Epoch 10/100
# 9/9 [==============================] - 8s 936ms/step - loss: 0.6212 - accuracy: 0.9271 - val_loss: 0.6231 - val_accuracy: 1.0000
# Epoch 11/100
# 9/9 [==============================] - 8s 892ms/step - loss: 0.6219 - accuracy: 0.9217 - val_loss: 0.6221 - val_accuracy: 1.0000
# Epoch 12/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6209 - accuracy: 0.9217 - val_loss: 0.6211 - val_accuracy: 1.0000
# Epoch 13/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.6200 - accuracy: 0.9362 - val_loss: 0.6201 - val_accuracy: 1.0000
# Epoch 14/100
# 9/9 [==============================] - 8s 919ms/step - loss: 0.6184 - accuracy: 0.9290 - val_loss: 0.6196 - val_accuracy: 1.0000
# Epoch 15/100
# 9/9 [==============================] - 9s 952ms/step - loss: 0.6195 - accuracy: 0.9308 - val_loss: 0.6186 - val_accuracy: 1.0000
# Epoch 16/100
# 9/9 [==============================] - 8s 934ms/step - loss: 0.6232 - accuracy: 0.9035 - val_loss: 0.6177 - val_accuracy: 1.0000
# Epoch 17/100
# 9/9 [==============================] - 8s 916ms/step - loss: 0.6176 - accuracy: 0.9308 - val_loss: 0.6171 - val_accuracy: 1.0000
# Epoch 18/100
# 9/9 [==============================] - 8s 894ms/step - loss: 0.6194 - accuracy: 0.9235 - val_loss: 0.6165 - val_accuracy: 1.0000
# Epoch 19/100
# 9/9 [==============================] - 9s 945ms/step - loss: 0.6152 - accuracy: 0.9417 - val_loss: 0.6158 - val_accuracy: 1.0000
# Epoch 20/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.6186 - accuracy: 0.9016 - val_loss: 0.6152 - val_accuracy: 1.0000
# Epoch 21/100
# 9/9 [==============================] - 8s 938ms/step - loss: 0.6163 - accuracy: 0.9035 - val_loss: 0.6149 - val_accuracy: 1.0000
# Epoch 22/100
# 9/9 [==============================] - 7s 810ms/step - loss: 0.6178 - accuracy: 0.9053 - val_loss: 0.6150 - val_accuracy: 1.0000
# Epoch 23/100
# 9/9 [==============================] - 8s 914ms/step - loss: 0.6158 - accuracy: 0.9016 - val_loss: 0.6137 - val_accuracy: 1.0000
# Epoch 24/100
# 9/9 [==============================] - 8s 931ms/step - loss: 0.6117 - accuracy: 0.9271 - val_loss: 0.6130 - val_accuracy: 1.0000
# Epoch 25/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6119 - accuracy: 0.9308 - val_loss: 0.6124 - val_accuracy: 1.0000
# Epoch 26/100
# 9/9 [==============================] - 8s 943ms/step - loss: 0.6151 - accuracy: 0.9016 - val_loss: 0.6118 - val_accuracy: 1.0000
# Epoch 27/100
# 9/9 [==============================] - 8s 932ms/step - loss: 0.6140 - accuracy: 0.9144 - val_loss: 0.6113 - val_accuracy: 1.0000
# Epoch 28/100
# 9/9 [==============================] - 9s 955ms/step - loss: 0.6125 - accuracy: 0.9362 - val_loss: 0.6108 - val_accuracy: 1.0000
# Epoch 29/100
# 9/9 [==============================] - 8s 870ms/step - loss: 0.6115 - accuracy: 0.9290 - val_loss: 0.6103 - val_accuracy: 1.0000
# Epoch 30/100
# 9/9 [==============================] - 8s 944ms/step - loss: 0.6120 - accuracy: 0.9162 - val_loss: 0.6098 - val_accuracy: 1.0000
# Epoch 31/100
# 9/9 [==============================] - 8s 919ms/step - loss: 0.6118 - accuracy: 0.9271 - val_loss: 0.6094 - val_accuracy: 1.0000
# Epoch 32/100
# 9/9 [==============================] - 9s 945ms/step - loss: 0.6119 - accuracy: 0.9016 - val_loss: 0.6090 - val_accuracy: 1.0000
# Epoch 33/100
# 9/9 [==============================] - 8s 891ms/step - loss: 0.6100 - accuracy: 0.9308 - val_loss: 0.6084 - val_accuracy: 1.0000
# Epoch 34/100
# 9/9 [==============================] - 8s 906ms/step - loss: 0.6086 - accuracy: 0.9235 - val_loss: 0.6079 - val_accuracy: 1.0000
# Epoch 35/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6097 - accuracy: 0.9126 - val_loss: 0.6075 - val_accuracy: 1.0000
# Epoch 36/100
# 9/9 [==============================] - 9s 945ms/step - loss: 0.6095 - accuracy: 0.9144 - val_loss: 0.6070 - val_accuracy: 1.0000
# Epoch 37/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.6112 - accuracy: 0.9053 - val_loss: 0.6064 - val_accuracy: 1.0000
# Epoch 38/100
# 9/9 [==============================] - 8s 934ms/step - loss: 0.6090 - accuracy: 0.9126 - val_loss: 0.6059 - val_accuracy: 1.0000
# Epoch 39/100
# 9/9 [==============================] - 8s 915ms/step - loss: 0.6053 - accuracy: 0.9435 - val_loss: 0.6052 - val_accuracy: 1.0000
# Epoch 40/100
# 9/9 [==============================] - 8s 928ms/step - loss: 0.6083 - accuracy: 0.9144 - val_loss: 0.6045 - val_accuracy: 1.0000
# Epoch 41/100
# 9/9 [==============================] - 9s 971ms/step - loss: 0.6061 - accuracy: 0.9235 - val_loss: 0.6045 - val_accuracy: 1.0000
# Epoch 42/100
# 9/9 [==============================] - 8s 875ms/step - loss: 0.6066 - accuracy: 0.9107 - val_loss: 0.6049 - val_accuracy: 0.9927
# Epoch 43/100
# 9/9 [==============================] - 8s 913ms/step - loss: 0.6041 - accuracy: 0.9290 - val_loss: 0.6024 - val_accuracy: 1.0000
# Epoch 44/100
# 9/9 [==============================] - 8s 914ms/step - loss: 0.6042 - accuracy: 0.9053 - val_loss: 0.6012 - val_accuracy: 1.0000
# Epoch 45/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.6017 - accuracy: 0.9308 - val_loss: 0.6006 - val_accuracy: 1.0000
# Epoch 46/100
# 9/9 [==============================] - 8s 942ms/step - loss: 0.6046 - accuracy: 0.9180 - val_loss: 0.6000 - val_accuracy: 1.0000
# Epoch 47/100
# 9/9 [==============================] - 9s 972ms/step - loss: 0.6028 - accuracy: 0.9199 - val_loss: 0.5995 - val_accuracy: 1.0000
# Epoch 48/100
# 9/9 [==============================] - 8s 926ms/step - loss: 0.6021 - accuracy: 0.9217 - val_loss: 0.5994 - val_accuracy: 1.0000
# Epoch 49/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.6010 - accuracy: 0.9144 - val_loss: 0.5984 - val_accuracy: 1.0000
# Epoch 50/100
# 9/9 [==============================] - 8s 933ms/step - loss: 0.6034 - accuracy: 0.9053 - val_loss: 0.5975 - val_accuracy: 1.0000
# Epoch 51/100
# 9/9 [==============================] - 8s 931ms/step - loss: 0.5994 - accuracy: 0.9235 - val_loss: 0.5968 - val_accuracy: 1.0000
# Epoch 52/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.5966 - accuracy: 0.9290 - val_loss: 0.5962 - val_accuracy: 1.0000
# Epoch 53/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.5950 - accuracy: 0.9271 - val_loss: 0.5955 - val_accuracy: 1.0000
# Epoch 54/100
# 9/9 [==============================] - 8s 923ms/step - loss: 0.5926 - accuracy: 0.9417 - val_loss: 0.5949 - val_accuracy: 1.0000
# Epoch 55/100
# 9/9 [==============================] - 8s 931ms/step - loss: 0.5990 - accuracy: 0.9089 - val_loss: 0.5943 - val_accuracy: 1.0000
# Epoch 56/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.5959 - accuracy: 0.9180 - val_loss: 0.5938 - val_accuracy: 1.0000
# Epoch 57/100
# 9/9 [==============================] - 8s 921ms/step - loss: 0.5944 - accuracy: 0.9217 - val_loss: 0.5932 - val_accuracy: 1.0000
# Epoch 58/100
# 9/9 [==============================] - 8s 939ms/step - loss: 0.5956 - accuracy: 0.9290 - val_loss: 0.5927 - val_accuracy: 1.0000
# Epoch 59/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.5940 - accuracy: 0.9217 - val_loss: 0.5921 - val_accuracy: 1.0000
# Epoch 60/100
# 9/9 [==============================] - 9s 950ms/step - loss: 0.5962 - accuracy: 0.9144 - val_loss: 0.5916 - val_accuracy: 1.0000
# Epoch 61/100
# 9/9 [==============================] - 8s 923ms/step - loss: 0.5916 - accuracy: 0.9271 - val_loss: 0.5911 - val_accuracy: 1.0000
# Epoch 62/100
# 9/9 [==============================] - 8s 940ms/step - loss: 0.5945 - accuracy: 0.9089 - val_loss: 0.5906 - val_accuracy: 1.0000
# Epoch 63/100
# 9/9 [==============================] - 9s 954ms/step - loss: 0.5949 - accuracy: 0.9144 - val_loss: 0.5900 - val_accuracy: 1.0000
# Epoch 64/100
# 9/9 [==============================] - 8s 915ms/step - loss: 0.5913 - accuracy: 0.9199 - val_loss: 0.5895 - val_accuracy: 1.0000
# Epoch 65/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.5890 - accuracy: 0.9217 - val_loss: 0.5890 - val_accuracy: 1.0000
# Epoch 66/100
# 9/9 [==============================] - 8s 928ms/step - loss: 0.5933 - accuracy: 0.9089 - val_loss: 0.5885 - val_accuracy: 1.0000
# Epoch 67/100
# 9/9 [==============================] - 8s 936ms/step - loss: 0.5892 - accuracy: 0.9162 - val_loss: 0.5880 - val_accuracy: 1.0000
# Epoch 68/100
# 9/9 [==============================] - 8s 925ms/step - loss: 0.5883 - accuracy: 0.9235 - val_loss: 0.5875 - val_accuracy: 1.0000
# Epoch 69/100
# 9/9 [==============================] - 8s 935ms/step - loss: 0.5892 - accuracy: 0.9126 - val_loss: 0.5870 - val_accuracy: 1.0000
# Epoch 70/100
# 9/9 [==============================] - 9s 946ms/step - loss: 0.5891 - accuracy: 0.9144 - val_loss: 0.5865 - val_accuracy: 1.0000
# Epoch 71/100
# 9/9 [==============================] - 8s 937ms/step - loss: 0.5926 - accuracy: 0.8907 - val_loss: 0.5860 - val_accuracy: 1.0000
# Epoch 72/100
# 9/9 [==============================] - 8s 943ms/step - loss: 0.5861 - accuracy: 0.9162 - val_loss: 0.5856 - val_accuracy: 1.0000
# Epoch 73/100
# 9/9 [==============================] - 8s 914ms/step - loss: 0.5828 - accuracy: 0.9417 - val_loss: 0.5851 - val_accuracy: 1.0000
# Epoch 74/100
# 9/9 [==============================] - 8s 907ms/step - loss: 0.5875 - accuracy: 0.9180 - val_loss: 0.5846 - val_accuracy: 1.0000
# Epoch 75/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.5879 - accuracy: 0.8998 - val_loss: 0.5841 - val_accuracy: 1.0000
# Epoch 76/100
# 9/9 [==============================] - 8s 922ms/step - loss: 0.5846 - accuracy: 0.9162 - val_loss: 0.5837 - val_accuracy: 1.0000
# Epoch 77/100
# 9/9 [==============================] - 9s 949ms/step - loss: 0.5859 - accuracy: 0.9235 - val_loss: 0.5833 - val_accuracy: 1.0000
# Epoch 78/100
# 9/9 [==============================] - 8s 906ms/step - loss: 0.5854 - accuracy: 0.9126 - val_loss: 0.5828 - val_accuracy: 1.0000
# Epoch 79/100
# 9/9 [==============================] - 8s 904ms/step - loss: 0.5872 - accuracy: 0.9180 - val_loss: 0.5823 - val_accuracy: 1.0000
# Epoch 80/100
# 9/9 [==============================] - 8s 918ms/step - loss: 0.5821 - accuracy: 0.9235 - val_loss: 0.5818 - val_accuracy: 1.0000
# Epoch 81/100
# 9/9 [==============================] - 8s 923ms/step - loss: 0.5811 - accuracy: 0.9271 - val_loss: 0.5813 - val_accuracy: 1.0000
# Epoch 82/100
# 9/9 [==============================] - 8s 940ms/step - loss: 0.5848 - accuracy: 0.9180 - val_loss: 0.5808 - val_accuracy: 1.0000
# Epoch 83/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.5821 - accuracy: 0.9253 - val_loss: 0.5803 - val_accuracy: 1.0000
# Epoch 84/100
# 9/9 [==============================] - 8s 908ms/step - loss: 0.5793 - accuracy: 0.9271 - val_loss: 0.5799 - val_accuracy: 1.0000
# Epoch 85/100
# 9/9 [==============================] - 8s 918ms/step - loss: 0.5806 - accuracy: 0.9126 - val_loss: 0.5794 - val_accuracy: 1.0000
# Epoch 86/100
# 9/9 [==============================] - 8s 910ms/step - loss: 0.5820 - accuracy: 0.9107 - val_loss: 0.5790 - val_accuracy: 1.0000
# Epoch 87/100
# 9/9 [==============================] - 8s 920ms/step - loss: 0.5826 - accuracy: 0.9107 - val_loss: 0.5785 - val_accuracy: 1.0000
# Epoch 88/100
# 9/9 [==============================] - 8s 860ms/step - loss: 0.5791 - accuracy: 0.9344 - val_loss: 0.5780 - val_accuracy: 1.0000
# Epoch 89/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.5801 - accuracy: 0.9235 - val_loss: 0.5776 - val_accuracy: 1.0000
# Epoch 90/100
# 9/9 [==============================] - 8s 921ms/step - loss: 0.5762 - accuracy: 0.9235 - val_loss: 0.5771 - val_accuracy: 1.0000
# Epoch 91/100
# 9/9 [==============================] - 8s 882ms/step - loss: 0.5764 - accuracy: 0.9253 - val_loss: 0.5767 - val_accuracy: 1.0000
# Epoch 92/100
# 9/9 [==============================] - 8s 912ms/step - loss: 0.5828 - accuracy: 0.9071 - val_loss: 0.5762 - val_accuracy: 1.0000
# Epoch 93/100
# 9/9 [==============================] - 8s 934ms/step - loss: 0.5788 - accuracy: 0.9107 - val_loss: 0.5758 - val_accuracy: 1.0000
# Epoch 94/100
# 9/9 [==============================] - 8s 928ms/step - loss: 0.5789 - accuracy: 0.9235 - val_loss: 0.5754 - val_accuracy: 1.0000
# Epoch 95/100
# 9/9 [==============================] - 8s 930ms/step - loss: 0.5744 - accuracy: 0.9344 - val_loss: 0.5749 - val_accuracy: 1.0000
# Epoch 96/100
# 9/9 [==============================] - 8s 913ms/step - loss: 0.5763 - accuracy: 0.9217 - val_loss: 0.5745 - val_accuracy: 1.0000
# Epoch 97/100
# 9/9 [==============================] - 8s 920ms/step - loss: 0.5798 - accuracy: 0.9089 - val_loss: 0.5740 - val_accuracy: 1.0000
# Epoch 98/100
# 9/9 [==============================] - 8s 891ms/step - loss: 0.5770 - accuracy: 0.9089 - val_loss: 0.5736 - val_accuracy: 1.0000
# Epoch 99/100
# 9/9 [==============================] - 8s 898ms/step - loss: 0.5746 - accuracy: 0.9199 - val_loss: 0.5731 - val_accuracy: 1.0000
# Epoch 100/100
# 9/9 [==============================] - 8s 924ms/step - loss: 0.5718 - accuracy: 0.9290 - val_loss: 0.5727 - val_accuracy: 1.0000

# %% [markdown]
# ## Train the model3

# %%
#convert to Core ML and check predictions
#your_model = coremltools.converters.keras.convert('/media/jacoblamkey/Storage/club and lax wheat/save_at_500.h5', 
#                                                  input_names=['image'], 
#                                                  output_names=['output'], 
#                                                 class_labels=output_labels, 
#                                                  image_input_names='image')
#your_model = coremltools.converters.keras.convert(model, input_names=['image'], output_names=['output'], 
#                                                   class_labels=output_labels, image_input_names='image')

# %%
import sys
import coremltools as ct
from coremltools.models.neural_network import quantization_utils

model = tf.keras.models.load_model('/media/jacoblamkey/Storage/club and lax wheat/val.9265.h5')
class_labels = ['Result']
image_input = ct.ImageType(shape=(1, 224, 224, 3,),
                           bias=[-1,-1,-1], scale=1/127)

# set class labels
classifier_config = ct.ClassifierConfig(class_labels)

# Convert the model using the Unified Conversion API

#classifier_config = ct.ClassifierConfig(class_labels)
your_model = ct.convert(model, inputs=[image_input], classifier_config=classifier_config, source='TensorFlow'
                        )
#nmt_model = "MT-Transformer.pb"

# Specifying that the sequence must be in [10, 20, 30, 40, 50]#
#shapes = [(1, 224+i, 255) for i in range(1, 6)]
#input_shape = ct.EnumeratedShapes(shapes=shapes)
#model_input = ct.TensorType(shape=input_shape)

# Convert the model
#your_model = ct.convert(model=nmt_model, inputs=[model_inputs])



your_model.author = 'Jake Lamkey'
your_model.short_description = 'Clasify Club and Lax wheat'
your_model.version = "1.0"

#your_model.input_description["input_1"] = "Input image to be classified"
your_model.output_description["classLabel"] = "Most likely image category"

#your_model.input_description['image'] = 'Takes an image and gives a class'
#your_model.output_description['output'] = 'Prediction of digit'
your_model.save('club.mlmodel')
#your_model = ct.models.MLModel('club.mlmodel')
#your_model16 = quantization_utils.quantize_weights(your_model, nbits=16)
#your_model16.save('club.json')


print(your_model)

# %%
spec=your_model.get_spec().

# %%
if len(sys.argv) != 3:
    print("USAGE: %s <input_mlmodel> <output_mlmodel>" % sys.argv[0])
    sys.exit(1)
input_model_path = sys.argv[1]
output_model_path = sys.argv[2]

# %%
output_model_path

# %% [markdown]
# Check predictions for MLCore

# %%
#strategy = tf.distribute.MirroredStrategy()
#print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

##with strategy.scope():
#+    model=make_model(input_shape=image_size + (3,), num_classes=2)

# %% [markdown]
# We get to ~96% validation accuracy after training for 50 epochs on the full dataset.

# %% [markdown]
# ## Run inference on new data
#
# Note that data augmentation and dropout are inactive at inference time.

# %%
img = keras.preprocessing.image.load_img(
    "/media/jacoblamkey/Storage/club and lax wheat/Test/14 CX DH PUL Entry 12.jpg", target_size=image_size
) #lax
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions
score
#print(
#    "This image is %.2f percent club and %.2f percent lax."
#    % (100 * (1 - score), 100 * score)
#)

# %%
img = keras.preprocessing.image.load_img(
    "/media/jacoblamkey/Storage/club and lax wheat/Test/14 CX DH PUL Entry 2.jpg", target_size=image_size
)#club
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent club and %.2f percent lax."
    % (100 * (1 - score), 100 * score)
)

# %%
img = keras.preprocessing.image.load_img(
    "/media/jacoblamkey/Storage/club and lax wheat/Test/14 CX DH PUL Entry 12.jpg", target_size=image_size
) #lax
#img_array = keras.preprocessing.image.img_to_array(img)
#img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(["/media/jacoblamkey/Storage/club and lax wheat/Test/14 CX DH PUL Entry 12.jpg"])
predictions

# %%
epoch = 50
# Define configuration parameters
start_lr = 0.01
rampup_epochs = 2
exp_decay = 0.01

# Define the scheduling function                                                                                         
 model.compile(
       optimizer=optimizer, loss=keras.losses.categorical_classification, metrics=["accuracy"])
 
model.fit(train_ds, epochs=epoch, callbacks=callbacks, validation_data=val_ds)

# %% [markdown]
# ## Two options to preprocess the data
#
# There are two ways you could be using the `data_augmentation` preprocessor:
#
# **Option 1: Make it part of the model**, like this:
#
# ```python
# inputs = keras.Input(shape=input_shape)
# x = data_augmentation(inputs)
# x = layers.experimental.preprocessing.Rescaling(1./255)(x)
# ...  # Rest of the model
# ```
#
# With this option, your data augmentation will happen *on device*, synchronously
# with the rest of the model execution, meaning that it will benefit from GPU
#  acceleration.
#
# Note that data augmentation is inactive at test time, so the input samples will only be
#  augmented during `fit()`, not when calling `evaluate()` or `predict()`.
#
# If you're training on GPU, this is the better option.
#
# **Option 2: apply it to the dataset**, so as to obtain a dataset that yields batches of
#  augmented images, like this:
#
# ```python
# augmented_train_ds = train_ds.map(
#   lambda x, y: (data_augmentation(x, training=True), y))
# ```
#
# With this option, your data augmentation will happen **on CPU**, asynchronously, and will
#  be buffered before going into the model.
#
# If you're training on CPU, this is the better option, since it makes data augmentation
#  asynchronous and non-blocking.
#
# In our case, we'll go with the first option.

# %%
#input_shape = image_size + (3,)
#num_classes = 2
def make_model(input_shape, num_classes):
    model = keras.Sequential()
    model.add(keras.Input(shape=input_shape))
    # Image augmentation block
    #x = data_augmentation(inputs)

    # Entry block
    #x = layers.experimental.preprocessing.Rescaling(1.0 / 255)(inputs)

    model.add(Conv2D(32, 3, strides=2, padding="same" ))
    model.add(BatchNormalization())
    model.add(Activation("relu"))

    model.add(Conv2D(64, 3, padding="same"))
    model.add(BatchNormalization())
    model.add((Activation("relu")))

    #previous_block_activation = model  # Set aside residual


    for size in [128, 256, 512, 728]:
        model.add(Activation("relu"))
        model.add(SeparableConv2D(size, 3, padding="same"))
        model.add(BatchNormalization())

        model.add(Activation("relu"))
        model.add(SeparableConv2D(size, 3, padding="same"))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(3, strides=2, padding="same"))

        # Project residual
        model.add(Conv2D(size, 1, strides=2, padding="same"))
        #model.add([residual])  # Add back residual
        #previous_block_activation = x  # Set aside next residual

    model.add(SeparableConv2D(1024, 3, padding="same"))
    model.add(BatchNormalization())
    model.add(Activation("relu"))

    model.add(GlobalAveragePooling2D())
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    model.add(Dropout(0.3))
    #activation = model.add(Dense(units, activation=activation))
    
    model.add(Dense(units, activation=activation))
    #return keras.Model(model, outputs)
#mets = [tf.keras.metrics.Precision(thresholds=None, top_k=None, class_id=None, name=None, dtype=None)]
#losses = [tf.keras.losses.CategoricalCrossentropy(from_logits=False,label_smoothing=0,reduction="auto",name="categorical_crossentropy",)]
    model.compile(
            optimizer=keras.optimizers.Adam(lr = 0.001),
            loss=keras.losses.binary_crossentropy,
            metrics =["accuracy"]
    )
    return(model)

#model.summary()

# %%
#epochs = 5  # @param {type: "slider", min:8, max:80}
#epoch = 2
# Define configuration parameters
#start_lr = 0.01
#rampup_epochs = 1
#exp_decay = 0.01

#strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
with strategy.scope():
    mob = tf.keras.applications.MobileNetV2(include_top=False, weights="imagenet", pooling="avg")
    mob.trainable = False

    model = keras.Sequential()
    #model.add(AveragePooling2D(input_shape=(224, 224, 3)))

    model.add(mob)
    model.add(keras.Input(shape=(224, 224, 3)))
    
    model.add(BatchNormalization())

    top_dropout_rate = 0.2
    model.add(Dropout(top_dropout_rate))
    model.add(BatchNormalization())

    #model.add(Dense(256, activation="softmax"))
    model.add(Dense(1, activation="sigmoid"))

    # Compile
    optimizer = keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss=tf.keras.losses.CategoricalCrossentropy(), metrics=["accuracy"])
    
    model.fit(train_ds, epochs=5, validation_data=val_ds, callbacks=callbacks
              #,steps_per_epoch=548/137,
             #    validation_steps=136/4
             )
    mob.trainable = True

    model.compile(
       optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"])
    model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=callbacks
             # ,steps_per_epoch=548/137,
               #  validation_steps=136/4
             )

       # mob.trainable = False
